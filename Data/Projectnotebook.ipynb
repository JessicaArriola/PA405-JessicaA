# %%
import geopandas as gpd

# %%
censustracts=gpd.read_file('LACountyTracts24.zip')

# %%
censustracts.head()
# Out:
#             ID          NAME  STATE_NAME ST_ABBREV      AREA  TOTPOP_CY  \
# 0  06037262302  060372623.02  California        CA  1.182838       2782
# 1  06037206201  060372062.01  California        CA  0.077543       2863
# 2  06037128102  060371281.02  California        CA  0.250507       4755
# 3  06037131701  060371317.01  California        CA  0.254699       4591
# 4  06037232800  060372328.00  California        CA  0.164729       3927
#
#    HHPOP_CY  GQPOP_CY  POPDENS_CY  TOTHH_CY  ...  NHSPWHT__1  NHSPBLK__1  \
# 0      2765        17      2352.0      1141  ...   79.295471    1.042416
# 1      2202       661     36941.9      1262  ...   20.852253   16.590988
# 2      4521       234     18982.0      1479  ...   18.401682    5.005258
# 3      4575        16     18025.1      1741  ...   23.175779    5.968199
# 4      3858        69     23843.4       968  ...    0.993125   12.554113
#
#    NHSPAI_CY_  NHSPASN__1  NHSPPI_CY_  NHSPOTH__1  NHSPMLT__1  HSGRAD_LES  \
# ...

# %%
columns_to_keep = ['ID',
                   'HISPPOP_CY', 
                   'EDUCBASECY',
                   'LOTRHH_CY',
                   'geometry']

# %%
censustractsCleaned = censustracts[columns_to_keep]

# %%
censustractsCleaned.columns = ['FIPS',
               'Hispanic Population',
               'Educational Base',
               'Low Income Tier',
               'geometry']

# %%
censustractsCleaned.head()
# Out:
#           FIPS  Hispanic Population  Educational Base  Low Income Tier  \
# 0  06037262302                  195              2063              160
# 1  06037206201                  767              2418              624
# 2  06037128102                 3265              3294              439
# 3  06037131701                 2064              3335              376
# 4  06037232800                 3282              2426              430
#
#                                             geometry
# 0  POLYGON ((-13187629.788 4038588.873, -13187642...
# 1  POLYGON ((-13162511.881 4035572.196, -13162582...
# 2  POLYGON ((-13184678.486 4053894.2, -13184921.4...
# 3  POLYGON ((-13197317.144 4055820.492, -13197556...
# 4  POLYGON ((-13166681.241 4028231.101, -13166681...

# %%
censustractsCleaned.type
# Out:
# 0            Polygon
# 1            Polygon
# 2            Polygon
# 3            Polygon
# 4            Polygon
#             ...
# 2528    MultiPolygon
# 2529         Polygon
# 2530         Polygon
# 2531         Polygon
# 2532    MultiPolygon
# Length: 2533, dtype: object

# %%
censustractsCleaned.plot()
# Out:
# <Axes: >

# %%
# !pip install mapclassify
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 882.2/882.2 kB 28.6 MB/s eta 0:00:00
# ...

# %%
censustractsCleaned.plot(figsize=(12,10),
                 column='Hispanic Population',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <Axes: >

# %%
censustractsCleaned.plot(figsize=(12,10),
                 column='Educational Base',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <Axes: >

# %%
columns_to_keep = ['ID', 'HISPPOP_CY', 'NHSPWHT_CY', 'NHSPBLK_CY', 'NHSPAI_CY', 'NHSPASN_CY', 'NHSPPI_CY', 'NHSPOTH_CY', 'NHSPMLT_CY', 'DIVINDX_CY', 'RACEBASECY', 'NOHS_CY', 'SOMEHS_CY', 'HSGRAD_CY', 'GED_CY', 'SMCOLL_CY', 'ASSCDEG_CY', 'BACHDEG_CY', 'GRADDEG_CY', 'EDUCBASECY', 'LOTRHH_CY', 'geometry']

# %%
censustractsCleaned = censustracts[columns_to_keep]

# %%
censustractsCleaned.head()
# Out:
#             ID  HISPPOP_CY  NHSPWHT_CY  NHSPBLK_CY  NHSPAI_CY  NHSPASN_CY  \
# 0  06037262302         195        2206          29          0         181
# 1  06037206201         767         597         475         29         825
# 2  06037128102        3265         875         238          2         267
# 3  06037131701        2064        1064         274          8         981
# 4  06037232800        3282          39         493         10          24
#
#    NHSPPI_CY  NHSPOTH_CY  NHSPMLT_CY  DIVINDX_CY  ...  SOMEHS_CY  HSGRAD_CY  \
# 0          0          28         143        41.7  ...          0         62
# 1         12          24         134        87.0  ...        211        367
# 2          7          32          69        82.8  ...        243        915
# 3          2          27         171        88.5  ...        286        747
# 4          0          35          44        71.7  ...        265        572
#
# ...

# %%
censustractsCleaned.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2533 entries, 0 to 2532
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          2533 non-null   object
#  1   HISPPOP_CY  2533 non-null   int64
#  2   NHSPWHT_CY  2533 non-null   int64
#  3   NHSPBLK_CY  2533 non-null   int64
#  4   NHSPAI_CY   2533 non-null   int64
#  5   NHSPASN_CY  2533 non-null   int64
#  6   NHSPPI_CY   2533 non-null   int64
#  7   NHSPOTH_CY  2533 non-null   int64
#  8   NHSPMLT_CY  2533 non-null   int64
#  9   DIVINDX_CY  2533 non-null   float64
#  10  RACEBASECY  2533 non-null   int64
#  11  NOHS_CY     2533 non-null   int64
#  12  SOMEHS_CY   2533 non-null   int64
#  13  HSGRAD_CY   2533 non-null   int64
#  14  GED_CY      2533 non-null   int64
#  15  SMCOLL_CY   2533 non-null   int64
#  16  ASSCDEG_CY  2533 non-null   int64
#  17  BACHDEG_CY  2533 non-null   int64
#  18  GRADDEG_CY  2533 non-null   int64
# ...

# %%
censustractsCleaned.shape
# Out:
# (2533, 22)

# %%
censustractsCleaned.describe()
# Out:
#         HISPPOP_CY   NHSPWHT_CY   NHSPBLK_CY    NHSPAI_CY   NHSPASN_CY  \
# count  2533.000000  2533.000000  2533.000000  2533.000000  2533.000000
# mean   1912.333597   959.699171   287.457560     7.103829   598.900908
# std    1321.468980   986.664479   456.497764     6.872504   725.789841
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%     785.000000   171.000000    55.000000     3.000000   147.000000
# 50%    1713.000000   585.000000   130.000000     5.000000   366.000000
# 75%    2807.000000  1501.000000   304.000000    10.000000   733.000000
# max    7303.000000  8753.000000  4690.000000    89.000000  5901.000000
#
#          NHSPPI_CY   NHSPOTH_CY   NHSPMLT_CY   DIVINDX_CY    RACEBASECY  \
# count  2533.000000  2533.000000  2533.000000  2533.000000   2533.000000
# mean      8.058824    21.862614   126.067509    75.357442   3921.484011
# std      15.104301    14.468796    97.955650    12.080802   1403.902380
# ...

# %%
censustractsCleaned.plot()
# Out:
# <Axes: >

# %%
# this is the hispanic population in LA County 
censustractsCleaned.plot(figsize=(12,10),
                 column='HISPPOP_CY',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <Axes: >

# %%
# this is the black population in Los Angeles County 
censustractsCleaned.plot(figsize=(12,10),
                 column='NHSPBLK_CY',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <Axes: >

# %%
# this is the white population in Los Angeles County 
censustractsCleaned.plot(figsize=(12,10),
                 column='NHSPWHT_CY',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <Axes: >

# %%
# this is the white population in Los Angeles County 
censustractsCleaned.plot(figsize=(12,10),
                 column='NHSPAI_CY',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <Axes: >

# %%
# this is the Asian population in Los Angeles County 
censustractsCleaned.plot(figsize=(12,10),
                 column='NHSPASN_CY',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <Axes: >

# %%
# this is the Pacific Islander population in Los Angeles County 
censustractsCleaned.plot(figsize=(12,10),
                 column='NHSPPI_CY',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <Axes: >

# %%
censustractsCleaned.plot(figsize=(12,10),
                 column='EDUCBASECY',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <Axes: >

# %%
# this is the population with less than 9th gradeeducation in Los Angeles County 
censustractsCleaned.plot(figsize=(12,10),
                 column='NOHS_CY',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <Axes: >

# %%
# this is the population with some HS Education but not graduated
censustractsCleaned.plot(figsize=(12,10),
                 column='SOMEHS_CY',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <Axes: >

# %%
# this is the population that are HS graduates 
censustractsCleaned.plot(figsize=(12,10),
                 column='HSGRAD_CY',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <Axes: >

# %%
# this is the population that have their GED
censustractsCleaned.plot(figsize=(12,10),
                 column='GED_CY',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <Axes: >

# %%
# this is the population that have some college eduationa however no degree 
censustractsCleaned.plot(figsize=(12,10),
                 column='SMCOLL_CY',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <Axes: >

# %%
# this is the population that have an associates degree
censustractsCleaned.plot(figsize=(12,10),
                 column='ASSCDEG_CY',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <Axes: >

# %%
# this is the population that have a bachelors degree
censustractsCleaned.plot(figsize=(12,10),
                 column='BACHDEG_CY',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <Axes: >

# %%
# this is the population that have a graduate/professional degree
censustractsCleaned.plot(figsize=(12,10),
                 column='GRADDEG_CY',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <Axes: >

# %%
censustractsCleaned.head(10).plot.barh(x='ID',
                            y='GRADDEG_CY', 
                            title='Top 10 Census Tracts with Highest Graduate Education in Los Angeles County in 2020',
                            color='pink')
# Out:
# <Axes: title={'center': 'Top 10 Census Tracts with Highest Graduate Education in Los Angeles County in 2020'}, ylabel='ID'>

# %%
censustractsCleaned.head(10).plot.barh(x='ID',
                            y='BACHDEG_CY', 
                            title='Top 10 Census Tracts with Highest Bachelors Education in Los Angeles County in 2020',
                            color='pink')
# Out:
# <Axes: title={'center': 'Top 10 Census Tracts with Highest Bachelors Education in Los Angeles County in 2020'}, ylabel='ID'>

# %%
censustractsCleaned.head(10).plot.barh(x='ID',
                            y='ASSCDEG_CY', 
                            title='Top 10 Census Tracts with Highest Associates Degree Education in Los Angeles County in 2020',
                            color='pink')
# Out:
# <Axes: title={'center': 'Top 10 Census Tracts with Highest Associates Degree Education in Los Angeles County in 2020'}, ylabel='ID'>

# %%
censustractsCleanedSort = censustractsCleaned.sort_values(by='GRADDEG_CY',ascending = False)

# %%
censustractsCleaned.head(10).plot(figsize=(12,10),
                 column='GRADDEG_CY',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <Axes: >

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
censustractsCleaned.describe()
# Out:
#         HISPPOP_CY   NHSPWHT_CY   NHSPBLK_CY    NHSPAI_CY   NHSPASN_CY  \
# count  2533.000000  2533.000000  2533.000000  2533.000000  2533.000000
# mean   1912.333597   959.699171   287.457560     7.103829   598.900908
# std    1321.468980   986.664479   456.497764     6.872504   725.789841
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%     785.000000   171.000000    55.000000     3.000000   147.000000
# 50%    1713.000000   585.000000   130.000000     5.000000   366.000000
# 75%    2807.000000  1501.000000   304.000000    10.000000   733.000000
# max    7303.000000  8753.000000  4690.000000    89.000000  5901.000000
#
#          NHSPPI_CY   NHSPOTH_CY   NHSPMLT_CY   DIVINDX_CY    RACEBASECY  \
# count  2533.000000  2533.000000  2533.000000  2533.000000   2533.000000
# mean      8.058824    21.862614   126.067509    75.357442   3921.484011
# std      15.104301    14.468796    97.955650    12.080802   1403.902380
# ...
